# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv(r'C:\Users\hknifton\OneDrive - Navigator Ltd\Desktop\Ontario election model\Valid Votes Cast For Each Candidate_2018.csv')
df = pd.read_csv(r'C:\Users\hknifton\OneDrive - Navigator Ltd\Desktop\Ontario election model\Valid Votes Cast For Each Candidate_2018.csv')
df

# https://results.elections.on.ca/en/publications - source
# Out:
#           EventNameEnglish            EventNameFrench  IsGeneralElection  \
# 0    2018 General Election  élection générale de 2018                  1
# 1    2018 General Election  élection générale de 2018                  1
# 2    2018 General Election  élection générale de 2018                  1
# 3    2018 General Election  élection générale de 2018                  1
# 4    2018 General Election  élection générale de 2018                  1
# ..                     ...                        ...                ...
# 818  2018 General Election  élection générale de 2018                  1
# 819  2018 General Election  élection générale de 2018                  1
# 820  2018 General Election  élection générale de 2018                  1
# 821  2018 General Election  élection générale de 2018                  1
# 822  2018 General Election  élection générale de 2018                  1
#
#      ElectoralDistrictNumber ElectoralDistrictNameEnglish  \
# ...

# %%
df2 = df.groupby(['ElectoralDistrictNameEnglish'])['TotalValidBallotsCast'].transform(max) == df['TotalValidBallotsCast']
df2018=df[df2]
df2018=df2018.replace({'LIB': 'OLP','PCP':'PC'}, regex=True)
#df2018['ElectoralDistrictNameEnglish'].replace({'P':''},regex=True)
df2018['ElectoralDistrictNameEnglish'] = df2018['ElectoralDistrictNameEnglish'].str.upper()
df2018
# Out:
#           EventNameEnglish            EventNameFrench  IsGeneralElection  \
# 2    2018 General Election  élection générale de 2018                  1
# 9    2018 General Election  élection générale de 2018                  1
# 15   2018 General Election  élection générale de 2018                  1
# 26   2018 General Election  élection générale de 2018                  1
# 31   2018 General Election  élection générale de 2018                  1
# ..                     ...                        ...                ...
# 793  2018 General Election  élection générale de 2018                  1
# 801  2018 General Election  élection générale de 2018                  1
# 807  2018 General Election  élection générale de 2018                  1
# 815  2018 General Election  élection générale de 2018                  1
# 816  2018 General Election  élection générale de 2018                  1
#
#      ElectoralDistrictNumber     ElectoralDistrictNameEnglish  \
# ...

# %%
PCPseats2018=sum(df2018.PoliticalInterestCode =='PC')
LIBseats2018=sum(df2018.PoliticalInterestCode =='OLP')
NDPseats2018=sum(df2018.PoliticalInterestCode =='NDP')
GPOseats2018=sum(df2018.PoliticalInterestCode =='GPO')

print(PCPseats2018,LIBseats2018,NDPseats2018,GPOseats2018)
# Out:
# 76 7 40 1

# %%
pd.read_csv(r'C:\Users\hknifton\OneDrive - Navigator Ltd\Desktop\Ontario election model\Valid Votes Cast For Each Candidate_2014.csv')
df2014 = pd.read_csv(r'C:\Users\hknifton\OneDrive - Navigator Ltd\Desktop\Ontario election model\Valid Votes Cast For Each Candidate_2014.csv')
df2014
# Out:
#              EventNameEnglish                     EventNameFrench  \
# 0    2012 - 2014 By Elections  élection partielles de 2012 - 2014
# 1    2012 - 2014 By Elections  élection partielles de 2012 - 2014
# 2    2012 - 2014 By Elections  élection partielles de 2012 - 2014
# 3    2012 - 2014 By Elections  élection partielles de 2012 - 2014
# 4    2012 - 2014 By Elections  élection partielles de 2012 - 2014
# ..                        ...                                 ...
# 685     2014 General Election           élection générale de 2014
# 686     2014 General Election           élection générale de 2014
# 687     2014 General Election           élection générale de 2014
# 688     2014 General Election           élection générale de 2014
# 689     2014 General Election           élection générale de 2014
#
#      IsGeneralElection  ElectoralDistrictNumber ElectoralDistrictNameEnglish  \
# 0                    0                       97                      VAUGHAN
# ...

# %%
df2014_2 = df2014.groupby(['ElectoralDistrictNameEnglish'])['TotalValidBallotsCast'].transform(max) == df2014['TotalValidBallotsCast']
df2014_3=df2014[df2014_2]
df2014_3=df2014_3.replace({'LIB': 'OLP','PCP':'PC'}, regex=True)
#df2014_3['ElectoralDistrictNameEnglish'].replace({'P':''},regex=True)
df2014_3['ElectoralDistrictNameEnglish'] = df2014_3['ElectoralDistrictNameEnglish'].str.upper()
df2014_3
# Out:
#           EventNameEnglish            EventNameFrench  IsGeneralElection  \
# 89   2014 General Election  élection générale de 2014                  1
# 92   2014 General Election  élection générale de 2014                  1
# 94   2014 General Election  élection générale de 2014                  1
# 96   2014 General Election  élection générale de 2014                  1
# 106  2014 General Election  élection générale de 2014                  1
# ..                     ...                        ...                ...
# 657  2014 General Election  élection générale de 2014                  1
# 662  2014 General Election  élection générale de 2014                  1
# 676  2014 General Election  élection générale de 2014                  1
# 680  2014 General Election  élection générale de 2014                  1
# 686  2014 General Election  élection générale de 2014                  1
#
#      ElectoralDistrictNumber ElectoralDistrictNameEnglish  \
# ...

# %%
PCPseats2014=sum(df2014_3.PoliticalInterestCode =='PC')
LIBseats2014=sum(df2014_3.PoliticalInterestCode =='OLP')
NDPseats2014=sum(df2014_3.PoliticalInterestCode =='NDP')
GPOseats2014=sum(df2014_3.PoliticalInterestCode =='GPO')

print(PCPseats2014,LIBseats2014,NDPseats2014,GPOseats2014)
# Out:
# 28 58 21 0

# %%
pd.read_csv(r'C:\Users\hknifton\OneDrive - Navigator Ltd\Desktop\Ontario election model\Valid Votes Cast For Each Candidate_2011.csv')
df2011 = pd.read_csv(r'C:\Users\hknifton\OneDrive - Navigator Ltd\Desktop\Ontario election model\Valid Votes Cast For Each Candidate_2011.csv')
df2011
# Out:
#              EventNameEnglish                     EventNameFrench  \
# 0    2008 - 2011 By Elections  élection partielles de 2008 - 2011
# 1    2008 - 2011 By Elections  élection partielles de 2008 - 2011
# 2    2008 - 2011 By Elections  élection partielles de 2008 - 2011
# 3    2008 - 2011 By Elections  élection partielles de 2008 - 2011
# 4    2008 - 2011 By Elections  élection partielles de 2008 - 2011
# ..                        ...                                 ...
# 687     2011 General Election           élection générale de 2011
# 688     2011 General Election           élection générale de 2011
# 689     2011 General Election           élection générale de 2011
# 690     2011 General Election           élection générale de 2011
# 691     2011 General Election           élection générale de 2011
#
#      IsGeneralElection  ElectoralDistrictNumber  \
# 0                    0                       29
# 1                    0                       29
# ...

# %%
df2011_2 = df2011.groupby(['ElectoralDistrictNameEnglish'])['TotalValidBallotsCast'].transform(max) == df2011['TotalValidBallotsCast']
df2011_3=df2011[df2011_2]
#df2011_3['ElectoralDistrictNameEnglish'].replace({'P':''},regex=True)
#df2011_3['ElectoralDistrictNameEnglish'] = df2011_3['ElectoralDistrictNameEnglish'].str.upper()
#df2011_3['PoliticalInterestCode']=df2011_3.replace({'L': 'OLP','PCP':'PC','ND':'NDP','G':'GPO'}, regex=True)
#instead of trying to do the above, don't chage the political interest codes are just count using the ones that are given in the data
df2011_3
# Out:
#           EventNameEnglish            EventNameFrench  IsGeneralElection  \
# 37   2011 General Election  élection générale de 2011                  1
# 47   2011 General Election  élection générale de 2011                  1
# 51   2011 General Election  élection générale de 2011                  1
# 52   2011 General Election  élection générale de 2011                  1
# 58   2011 General Election  élection générale de 2011                  1
# ..                     ...                        ...                ...
# 666  2011 General Election  élection générale de 2011                  1
# 675  2011 General Election  élection générale de 2011                  1
# 679  2011 General Election  élection générale de 2011                  1
# 683  2011 General Election  élection générale de 2011                  1
# 689  2011 General Election  élection générale de 2011                  1
#
#      ElectoralDistrictNumber           ElectoralDistrictNameEnglish  \
# ...

# %%
PCPseats2011=sum(df2011_3.PoliticalInterestCode =='PC')
LIBseats2011=sum(df2011_3.PoliticalInterestCode =='L')
NDPseats2011=sum(df2011_3.PoliticalInterestCode =='ND')
GPOseats2011=sum(df2011_3.PoliticalInterestCode =='G')

print(PCPseats2011,LIBseats2011,NDPseats2011,GPOseats2011)
# Out:
# 37 53 17 0

# %%
pd.read_csv(r'C:\Users\hknifton\OneDrive - Navigator Ltd\Desktop\Ontario election model\Valid Votes Cast For Each Candidate_2007.csv')
df2007 = pd.read_csv(r'C:\Users\hknifton\OneDrive - Navigator Ltd\Desktop\Ontario election model\Valid Votes Cast For Each Candidate_2007.csv')
df2007
# Out:
#           EventNameEnglish            EventNameFrench  IsGeneralElection  \
# 0    2007 General Election  élection générale de 2007                  1
# 1    2007 General Election  élection générale de 2007                  1
# 2    2007 General Election  élection générale de 2007                  1
# 3    2007 General Election  élection générale de 2007                  1
# 4    2007 General Election  élection générale de 2007                  1
# ..                     ...                        ...                ...
# 594  2007 General Election  élection générale de 2007                  1
# 595  2007 General Election  élection générale de 2007                  1
# 596  2007 General Election  élection générale de 2007                  1
# 597  2007 General Election  élection générale de 2007                  1
# 598  2007 General Election  élection générale de 2007                  1
#
#      ElectoralDistrictNumber     ElectoralDistrictNameEnglish  \
# ...

# %%
df2007_2 = df2007.groupby(['ElectoralDistrictNameEnglish'])['TotalValidBallotsCast'].transform(max) == df2007['TotalValidBallotsCast']
df2007_3=df2007[df2007_2]
#df2007_3=df2007_3.replace({'L': 'OLP','PCP':'PC','ND':'NDP','G':'GPO'}, regex=True)
df2007_3
# Out:
#           EventNameEnglish            EventNameFrench  IsGeneralElection  \
# 1    2007 General Election  élection générale de 2007                  1
# 2    2007 General Election  élection générale de 2007                  1
# 3    2007 General Election  élection générale de 2007                  1
# 12   2007 General Election  élection générale de 2007                  1
# 17   2007 General Election  élection générale de 2007                  1
# ..                     ...                        ...                ...
# 567  2007 General Election  élection générale de 2007                  1
# 584  2007 General Election  élection générale de 2007                  1
# 587  2007 General Election  élection générale de 2007                  1
# 591  2007 General Election  élection générale de 2007                  1
# 595  2007 General Election  élection générale de 2007                  1
#
#      ElectoralDistrictNumber     ElectoralDistrictNameEnglish  \
# ...

# %%
PCPseats2007=sum(df2007_3.PoliticalInterestCode =='PC')
LIBseats2007=sum(df2007_3.PoliticalInterestCode =='L')
NDPseats2007=sum(df2007_3.PoliticalInterestCode =='ND')
GPOseats2007=sum(df2007_3.PoliticalInterestCode =='G')

print(PCPseats2007,LIBseats2007,NDPseats2007,GPOseats2007)

#these are different than wikipedia numbers - look into
# Out:
# 26 71 10 0

# %%
pd.read_csv(r'C:\Users\hknifton\OneDrive - Navigator Ltd\Desktop\Ontario election model\Valid Votes Cast For Each Candidate_2003.csv')
df2003 = pd.read_csv(r'C:\Users\hknifton\OneDrive - Navigator Ltd\Desktop\Ontario election model\Valid Votes Cast For Each Candidate_2003.csv')
df2003=df2003.replace({'-': '—'}, regex=True)
df2003
# Out:
#              EventNameEnglish                     EventNameFrench  \
# 0    2000 — 2002 By Elections  élection partielles de 2000 — 2002
# 1    2000 — 2002 By Elections  élection partielles de 2000 — 2002
# 2    2000 — 2002 By Elections  élection partielles de 2000 — 2002
# 3    2000 — 2002 By Elections  élection partielles de 2000 — 2002
# 4    2000 — 2002 By Elections  élection partielles de 2000 — 2002
# ..                        ...                                 ...
# 551     2003 General Election           élection générale de 2003
# 552     2003 General Election           élection générale de 2003
# 553     2003 General Election           élection générale de 2003
# 554     2003 General Election           élection générale de 2003
# 555     2003 General Election           élection générale de 2003
#
#      IsGeneralElection  ElectoralDistrictNumber  \
# 0                    0                       95
# 1                    0                       95
# ...

# %%
df2003_2 = df2003.groupby(['ElectoralDistrictNameEnglish'])['TotalValidBallotsCast'].transform(max) == df2003['TotalValidBallotsCast']
df2003_3=df2003[df2003_2]
#df2003_3=df2003_3.replace({'L': 'OLP','PCP':'PC','ND':'NDP','G':'GPO'}, regex=True)
df2003_3
# Out:
#           EventNameEnglish            EventNameFrench  IsGeneralElection  \
# 36   2003 General Election  élection générale de 2003                  1
# 38   2003 General Election  élection générale de 2003                  1
# 42   2003 General Election  élection générale de 2003                  1
# 46   2003 General Election  élection générale de 2003                  1
# 49   2003 General Election  élection générale de 2003                  1
# ..                     ...                        ...                ...
# 530  2003 General Election  élection générale de 2003                  1
# 538  2003 General Election  élection générale de 2003                  1
# 542  2003 General Election  élection générale de 2003                  1
# 543  2003 General Election  élection générale de 2003                  1
# 547  2003 General Election  élection générale de 2003                  1
#
#      ElectoralDistrictNumber     ElectoralDistrictNameEnglish  \
# ...

# %%
PCPseats2003=sum(df2003_3.PoliticalInterestCode =='PC')
LIBseats2003=sum(df2003_3.PoliticalInterestCode =='L')
NDPseats2003=sum(df2003_3.PoliticalInterestCode =='ND')
GPOseats2003=sum(df2003_3.PoliticalInterestCode =='G')

print(PCPseats2003,LIBseats2003,NDPseats2003,GPOseats2003)
# Out:
# 24 72 7 0

# %%
pd.read_csv(r'C:\Users\hknifton\OneDrive - Navigator Ltd\Desktop\Ontario election model\Valid Votes Cast For Each Candidate_1999.csv')
df1999 = pd.read_csv(r'C:\Users\hknifton\OneDrive - Navigator Ltd\Desktop\Ontario election model\Valid Votes Cast For Each Candidate_1999.csv')
df1999=df1999.replace({'-': '—'}, regex=True)
df1999
# Out:
#              EventNameEnglish                     EventNameFrench  \
# 0    1996 — 1998 By Elections  élection partielles de 1996 — 1998
# 1    1996 — 1998 By Elections  élection partielles de 1996 — 1998
# 2    1996 — 1998 By Elections  élection partielles de 1996 — 1998
# 3    1996 — 1998 By Elections  élection partielles de 1996 — 1998
# 4    1996 — 1998 By Elections  élection partielles de 1996 — 1998
# ..                        ...                                 ...
# 586     1999 General Election           élection générale de 1999
# 587     1999 General Election           élection générale de 1999
# 588     1999 General Election           élection générale de 1999
# 589     1999 General Election           élection générale de 1999
# 590     1999 General Election           élection générale de 1999
#
#      IsGeneralElection  ElectoralDistrictNumber ElectoralDistrictNameEnglish  \
# 0                    0                      129                   YORK SOUTH
# ...

# %%
df1999_2 = df1999.groupby(['ElectoralDistrictNameEnglish'])['TotalValidBallotsCast'].transform(max) == df1999['TotalValidBallotsCast']
df1999_3=df1999[df1999_2]
#df1999_3=df1999_3.replace({'L': 'OLP','PCP':'PC','ND':'NDP','G':'GPO'}, regex=True)
df1999_3
# Out:
#              EventNameEnglish                     EventNameFrench  \
# 2    1996 — 1998 By Elections  élection partielles de 1996 — 1998
# 10   1996 — 1998 By Elections  élection partielles de 1996 — 1998
# 12   1996 — 1998 By Elections  élection partielles de 1996 — 1998
# 19   1996 — 1998 By Elections  élection partielles de 1996 — 1998
# 23      1999 General Election           élection générale de 1999
# ..                        ...                                 ...
# 562     1999 General Election           élection générale de 1999
# 568     1999 General Election           élection générale de 1999
# 572     1999 General Election           élection générale de 1999
# 583     1999 General Election           élection générale de 1999
# 584     1999 General Election           élection générale de 1999
#
#      IsGeneralElection  ElectoralDistrictNumber ElectoralDistrictNameEnglish  \
# 2                    0                      129                   YORK SOUTH
# ...

# %%
PCPseats1999=sum(df1999_3.PoliticalInterestCode =='PC')
LIBseats1999=sum(df1999_3.PoliticalInterestCode =='L')
NDPseats1999=sum(df1999_3.PoliticalInterestCode =='ND')
GPOseats1999=sum(df1999_3.PoliticalInterestCode =='G')

print(PCPseats1999,LIBseats1999,NDPseats1999,GPOseats1999)
# Out:
# 59 38 10 0

# %%
print("2018 results:","PC=", PCPseats2018,"OLP=",LIBseats2018,"NDP=",NDPseats2018,"GPO=",GPOseats2018)
print("2014 results:","PC=", PCPseats2014,"OLP=",LIBseats2014,"NDP=",NDPseats2014,"GPO=",GPOseats2014)
print("2011 results:","PC=", PCPseats2011,"OLP=",LIBseats2011,"NDP=",NDPseats2011,"GPO=",GPOseats2011)
print("2007 results:","PC=", PCPseats2007,"OLP=",LIBseats2007,"NDP=",NDPseats2007,"GPO=",GPOseats2007)
print("2003 results:","PC=", PCPseats2003,"OLP=",LIBseats2003,"NDP=",NDPseats2003,"GPO=",GPOseats2003)
print("1999 results:","PC=", PCPseats1999,"OLP=",LIBseats1999,"NDP=",NDPseats1999,"GPO=",GPOseats1999)
# Out:
# 2018 results: PC= 76 OLP= 7 NDP= 40 GPO= 1
# 2014 results: PC= 28 OLP= 58 NDP= 21 GPO= 0
# 2011 results: PC= 37 OLP= 53 NDP= 17 GPO= 0
# 2007 results: PC= 26 OLP= 71 NDP= 10 GPO= 0
# 2003 results: PC= 24 OLP= 72 NDP= 7 GPO= 0
# 1999 results: PC= 59 OLP= 38 NDP= 10 GPO= 0

# %%
df2018Ridings=df2018.loc[df2018['PoliticalInterestCode'] == 'PC']
df2014Ridings=df2014_3.loc[df2014_3['PoliticalInterestCode']=='OLP']
df2011Ridings=df2011_3.loc[df2011_3['PoliticalInterestCode']=='L']
df2007Ridings=df2007_3.loc[df2007_3['PoliticalInterestCode']=='L']
df2003Ridings=df2003_3.loc[df2003_3['PoliticalInterestCode']=='L']
df1999Ridings=df1999_3.loc[df1999_3['PoliticalInterestCode']=='PC']

len(df2018Ridings.index), len(df2014Ridings.index), len(df2011Ridings.index), len(df2007Ridings.index), len(df2003Ridings.index), len(df1999Ridings.index)
# Out:
# (76, 58, 53, 71, 72, 59)

# %%
Ridings2018= df2018Ridings['ElectoralDistrictNameEnglish'].tolist()
Ridings2014= df2014Ridings['ElectoralDistrictNameEnglish'].tolist()
Ridings2011= df2011Ridings['ElectoralDistrictNameEnglish'].tolist()
Ridings2007= df2007Ridings['ElectoralDistrictNameEnglish'].tolist()
Ridings2003= df2003Ridings['ElectoralDistrictNameEnglish'].tolist()
Ridings1999= df1999Ridings['ElectoralDistrictNameEnglish'].tolist()

Ridings2003
# Out:
# ['BRAMALEA—GORE—MALTON—SPRINGDALE',
#  'SCARBOROUGH CENTRE',
#  'BRAMPTON CENTRE',
#  'PICKERING—AJAX—UXBRIDGE',
#  'TIMISKAMING—COCHRANE',
#  'KITCHENER CENTRE',
#  'YORK SOUTH—WESTON',
#  'SCARBOROUGH EAST',
#  'SUDBURY',
#  'WINDSOR—ST. CLAIR',
#  'THUNDER BAY—SUPERIOR NORTH',
#  'LONDON—FANSHAWE',
#  'LONDON WEST',
#  'PARKDALE—HIGH PARK',
#  'OTTAWA—VANIER',
#  'OTTAWA SOUTH',
#  'SARNIA—LAMBTON',
#  'HURON—BRUCE',
#  'VAUGHAN—KING—AURORA',
#  'NIAGARA FALLS',
#  'PETERBOROUGH',
#  'SCARBOROUGH—AGINCOURT',
#  'GLENGARRY—PRESCOTT—RUSSELL',
#  'SAULT STE. MARIE',
#  'MISSISSAUGA WEST',
#  'MARKHAM',
#  'OAKVILLE',
#  'OTTAWA CENTRE',
#  'EGLINTON—LAWRENCE',
#  'ELGIN—MIDDLESEX—LONDON',
#  'STORMONT—DUNDAS—CHARLOTTENBURGH',
#  'WILLOWDALE',
#  'PERTH—MIDDLESEX',
#  'DON VALLEY WEST',
#  'LAMBTON—KENT—MIDDLESEX',
#  'MISSISSAUGA EAST',
#  'GUELPH—WELLINGTON',
#  'HAMILTON MOUNTAIN',
#  'THUNDER BAY—ATIKOKAN',
#  'YORK WEST',
#  'PRINCE EDWARD—HASTINGS',
#  'THORNHILL',
# ...

# %%
Ridings2014_set = set(Ridings2014)
Ridings2018_set = set(Ridings2018)
intersection2018_2014 = Ridings2018_set.intersection(Ridings2014)

intersection2018_2014 = list(intersection2018_2014)

#print(intersection2018_2014)

Ridings2011_set=set(Ridings2011)
intersection2018_2014_2011=Ridings2011_set.intersection(intersection2018_2014)

intersection2018_2014_2011 = list(intersection2018_2014_2011)

#print(intersection2018_2014_2011)

Ridings2007_set=set(Ridings2007)
intersection2018_2014_2011_2007=Ridings2007_set.intersection(intersection2018_2014_2011)

intersection2018_2014_2011_2007 = list(intersection2018_2014_2011_2007)

#print(intersection2018_2014_2011_2007)

Ridings2003_set=set(Ridings2003)
intersection2018_2014_2011_2007_2003=Ridings2003_set.intersection(intersection2018_2014_2011_2007)

intersection2018_2014_2011_2007_2003 = list(intersection2018_2014_2011_2007_2003)

#print(intersection2018_2014_2011_2007_2003)
#lose a bunch here need to figure out why

Ridings1999_set=set(Ridings1999)
intersection2018_2014_2011_2007_2003_1999=Ridings1999_set.intersection(intersection2018_2014_2011_2007_2003)

intersection2018_2014_2011_2007_2003_1999 = list(intersection2018_2014_2011_2007_2003_1999)

print(intersection2018_2014_2011_2007_2003_1999)
# Out:
# ['SCARBOROUGH CENTRE', 'ETOBICOKE NORTH', 'OAKVILLE', 'OTTAWA WEST—NEPEAN', 'ETOBICOKE—LAKESHORE', 'WILLOWDALE', 'ETOBICOKE CENTRE']
